# %% [markdown]
# # PixelPrism Math Operators – LaTeX gallery

# %% [markdown]
# This notebook demonstrates how every public operator exposed through
# ``pixelprism.math.functional`` renders to LaTeX. Each cell builds a small
# symbolic expression, converts it with ``pixelprism.math.render.to_latex``, and
# shows the MathJax output for quick visual inspection.

# %%
import pixelprism.math as pm
import pixelprism.math.functional as F
from pixelprism.math.math_base import SliceExpr
from pixelprism.math.render import to_latex
from pixelprism.math.functional.helpers import apply_operator
from IPython.display import Math, display

scalar_a = pm.var("a", dtype=pm.DType.FLOAT32, shape=())
scalar_b = pm.var("b", dtype=pm.DType.FLOAT32, shape=())
scalar_c = pm.var("c", dtype=pm.DType.FLOAT32, shape=())
vector_u = pm.var("u", dtype=pm.DType.FLOAT32, shape=(3,))
vector_v = pm.var("v", dtype=pm.DType.FLOAT32, shape=(3,))
vector_w = pm.var("w", dtype=pm.DType.FLOAT32, shape=(2,))
matrix_A = pm.var("A", dtype=pm.DType.FLOAT32, shape=(3, 3))
matrix_B = pm.var("B", dtype=pm.DType.FLOAT32, shape=(3, 3))
matrix_C = pm.var("C", dtype=pm.DType.FLOAT32, shape=(1, 3))
matrix_D = pm.const("D", data=[[1, 2, 3], [4, 5, 6]], dtype=pm.DType.INT32)
tensor_T = pm.var("T", dtype=pm.DType.FLOAT32, shape=(3, 4, 5))
bounded_i = pm.var("i", dtype=pm.DType.FLOAT32, shape=())
bool_vector_mask = pm.var("mask", dtype=pm.DType.BOOL, shape=(3,))
bool_matrix_flags = pm.var("flags", dtype=pm.DType.BOOL, shape=(2, 2))
bool_vector_mask_rhs = pm.var("mask\_rhs", dtype=pm.DType.BOOL, shape=(3,))
bool_matrix_flags_rhs = pm.var("flags\_rhs", dtype=pm.DType.BOOL, shape=(2, 2))

clip_min = pm.const("clip_min", data=-1.0, dtype=pm.DType.FLOAT32)
clip_max = pm.const("clip_max", data=1.0, dtype=pm.DType.FLOAT32)


def render_cases(cases):
    for label, builder in cases:
        expr = builder()
        latex = to_latex(expr)
        display(Math(rf"\text{{{label}}} = {latex}"))

# %% [markdown]
# ## Elementwise, exponential, and logarithmic operators

# %%
elementwise_cases = [
    ("add", lambda: F.add(scalar_a, scalar_b)),
    ("sub", lambda: F.sub(scalar_a, scalar_b)),
    ("mul", lambda: F.mul(scalar_a, scalar_b)),
    ("div", lambda: F.div(scalar_a, scalar_b)),
    ("pow", lambda: F.pow(scalar_a, scalar_b)),
    ("exp", lambda: F.exp(scalar_a)),
    ("exp2", lambda: F.exp2(scalar_a)),
    ("expm1", lambda: F.expm1(scalar_a)),
    ("log", lambda: F.log(scalar_c)),
    ("log1p", lambda: F.log1p(scalar_c)),
    ("log2", lambda: F.log2(scalar_c)),
    ("log10", lambda: F.log10(scalar_c)),
    ("sqrt", lambda: F.sqrt(scalar_c)),
    ("square", lambda: F.square(scalar_c)),
    ("cbrt", lambda: F.cbrt(scalar_c)),
    ("reciprocal", lambda: F.reciprocal(scalar_c)),
    ("deg2rad", lambda: F.deg2rad(scalar_a)),
    ("rad2deg", lambda: F.rad2deg(scalar_a)),
    ("absolute", lambda: F.absolute(F.sub(scalar_a, scalar_b))),
    ("abs", lambda: F.abs(F.sub(scalar_a, scalar_b))),
    ("neg", lambda: F.neg(scalar_a)),
]

render_cases(elementwise_cases)
# Out:
# $\displaystyle \text{add} = a + b$
# $\displaystyle \text{sub} = a - b$
# $\displaystyle \text{mul} = a \cdot b$
# $\displaystyle \text{div} = \frac{a}{b}$
# $\displaystyle \text{pow} = a^{b}$
# $\displaystyle \text{exp} = e^{a}$
# $\displaystyle \text{exp2} = 2^{a}$
# $\displaystyle \text{expm1} = \operatorname{expm1}\left(a\right)$
# $\displaystyle \text{log} = \log\left(c\right)$
# $\displaystyle \text{log1p} = \operatorname{log1p}\left(c\right)$
# $\displaystyle \text{log2} = \log_{2}({c})$
# $\displaystyle \text{log10} = \log_{10}({c})$
# $\displaystyle \text{sqrt} = \sqrt{c}$
# $\displaystyle \text{square} = c^2$
# $\displaystyle \text{cbrt} = \sqrt[3]{c}$
# $\displaystyle \text{reciprocal} = \frac{1}{c}$
# $\displaystyle \text{deg2rad} = \operatorname{deg2rad}\left(a\right)$
# $\displaystyle \text{rad2deg} = \operatorname{rad2deg}\left(a\right)$
# $\displaystyle \text{absolute} = \left|{\left(a - b\right)} \right|$
# $\displaystyle \text{abs} = \left|{\left(a - b\right)} \right|$
# $\displaystyle \text{neg} = -a$

# %% [markdown]
# ## Discretization operators

# %%
discretization_cases = [
    ("sign", lambda: F.sign(vector_u)),
    ("floor", lambda: F.floor(scalar_a)),
    ("ceil", lambda: F.ceil(scalar_a)),
    ("trunc", lambda: F.trunc(scalar_a)),
    ("rint", lambda: F.rint(scalar_a)),
    ("round (decimals=2)", lambda: F.round(scalar_a, decimals=2)),
    ("clip", lambda: F.clip(vector_v, min_value=clip_min, max_value=clip_max)),
]

render_cases(discretization_cases)
# Out:
# $\displaystyle \text{sign} = \mathrm{sgn}({u})$
# $\displaystyle \text{floor} = \lfloor{a} \rfloor$
# $\displaystyle \text{ceil} = \lceil{a} \rceil$
# $\displaystyle \text{trunc} = \operatorname{trunc}\left(a\right)$
# $\displaystyle \text{rint} = \operatorname{rint}\left(a\right)$
# $\displaystyle \text{round (decimals=2)} = \operatorname{round}({a}, {2})$
# $\displaystyle \text{clip} = \operatorname{clip}({v}, {-\infty}, {\infty})$

# %% [markdown]
# ## Trigonometric operators

# %%
trig_cases = [
    ("sin", lambda: F.sin(scalar_b)),
    ("cos", lambda: F.cos(scalar_b)),
    ("tan", lambda: F.tan(scalar_b)),
    ("asin", lambda: F.asin(scalar_b)),
    ("acos", lambda: F.acos(scalar_b)),
    ("atan", lambda: F.atan(scalar_b)),
    ("atan2", lambda: F.atan2(scalar_a, scalar_b)),
    ("sec", lambda: F.sec(scalar_b)),
    ("csc", lambda: F.csc(scalar_b)),
    ("cot", lambda: F.cot(scalar_b)),
    ("sinh", lambda: F.sinh(scalar_b)),
    ("cosh", lambda: F.cosh(scalar_b)),
    ("tanh", lambda: F.tanh(scalar_b)),
    ("asinh", lambda: F.asinh(scalar_b)),
    ("acosh", lambda: F.acosh(scalar_b)),
    ("atanh", lambda: F.atanh(scalar_b)),
]

render_cases(trig_cases)
# Out:
# $\displaystyle \text{sin} = \sin\left(b\right)$
# $\displaystyle \text{cos} = \cos\left(b\right)$
# $\displaystyle \text{tan} = \tan\left(b\right)$
# $\displaystyle \text{asin} = \operatorname{asin}\left(b\right)$
# $\displaystyle \text{acos} = \operatorname{acos}\left(b\right)$
# $\displaystyle \text{atan} = \operatorname{atan}\left(b\right)$
# $\displaystyle \text{atan2} = \operatorname{atan2}\left(a, b\right)$
# $\displaystyle \text{sec} = \operatorname{sec}\left(b\right)$
# $\displaystyle \text{csc} = \operatorname{csc}\left(b\right)$
# $\displaystyle \text{cot} = \operatorname{cot}\left(b\right)$
# $\displaystyle \text{sinh} = \operatorname{sinh}\left(b\right)$
# $\displaystyle \text{cosh} = \operatorname{cosh}\left(b\right)$
# $\displaystyle \text{tanh} = \operatorname{tanh}\left(b\right)$
# $\displaystyle \text{asinh} = \operatorname{asinh}\left(b\right)$
# $\displaystyle \text{acosh} = \operatorname{acosh}\left(b\right)$
# $\displaystyle \text{atanh} = \operatorname{atanh}\left(b\right)$

# %% [markdown]
# ## Linear algebra operators

# %%
linear_algebra_cases = [
    ("matmul", lambda: F.matmul(matrix_A, matrix_B)),
    ("dot", lambda: F.dot(vector_u, vector_v)),
    ("outer", lambda: F.outer(vector_u, vector_v)),
    ("trace", lambda: F.trace(matrix_A)),
    ("transpose", lambda: F.transpose(tensor_T, axes=(2, 1, 0))),
    ("det", lambda: F.det(matrix_A)),
    ("inverse", lambda: F.inverse(matrix_A)),
    ("norm", lambda: F.norm(vector_w, order=2)),
    ("infty_norm", lambda: F.infty_norm(vector_w)),
    ("frobenius_norm", lambda: F.frobenius_norm(matrix_A)),
]

render_cases(linear_algebra_cases)
# Out:
# $\displaystyle \text{matmul} = AB$
# $\displaystyle \text{dot} = u \cdot v$
# $\displaystyle \text{outer} = u \otimes v$
# $\displaystyle \text{trace} = \operatorname{trace}\left(A\right)$
# $\displaystyle \text{transpose} = T^{\mathsf{T}}$
# $\displaystyle \text{det} = \operatorname{det}\left(A\right)$
# $\displaystyle \text{inverse} = A^{-1}$
# $\displaystyle \text{norm} = \left\Vert{w}\right\Vert_{2}$
# $\displaystyle \text{infty\_norm} = \lVert w \rVert_\infty$
# $\displaystyle \text{frobenius\_norm} = \lVert A \rVert_F$

# %% [markdown]
# ## Reduction operators

# %%
reduction_cases = [
    ("sum", lambda: F.sum(tensor_T, axis=0)),
    ("mean", lambda: F.mean(tensor_T, axis=1)),
    ("std", lambda: F.std(tensor_T, axis=2)),
    ("median", lambda: F.median(tensor_T, axis=0)),
    ("max", lambda: F.max(tensor_T, axis=1)),
    ("min", lambda: F.min(tensor_T, axis=2)),
    ("q1", lambda: F.q1(tensor_T, axis=0)),
    ("q3", lambda: F.q3(tensor_T, axis=1)),
    ("summation", lambda: F.summation(F.mul(bounded_i, scalar_a), lower=1, upper=5, i="i")),
    ("product", lambda: F.product(F.add(bounded_i, scalar_a), lower=1, upper=4, i="i")),
]

render_cases(reduction_cases)
# Out:
# $\displaystyle \text{sum} = \operatorname{sum}(T)$
# $\displaystyle \text{mean} = \operatorname{mean}(T)$
# $\displaystyle \text{std} = \sigma(T)$
# $\displaystyle \text{median} = \operatorname{median}\left(T\right)$
# $\displaystyle \text{max} = \operatorname{max}\left(T\right)$
# $\displaystyle \text{min} = \operatorname{min}\left(T\right)$
# $\displaystyle \text{q1} = \operatorname{q_1}({T})$
# $\displaystyle \text{q3} = \operatorname{q_3}({T})$
# $\displaystyle \text{summation} = \sum_{i=1}^{5}{\left(i \cdot a\right)}$
# $\displaystyle \text{product} = \prod_{i=1}^{4}{\left(i + a\right)}$

# %% [markdown]
# ## Structure operator

# %%
getitem_cases = [
    (
        "getitem",
        lambda: F.getitem(
            tensor_T,
            indices=[
                SliceExpr.create(0, 3, 2),
                SliceExpr.create(1, 4, 2),
                1,
            ],
        ),
    )
]

render_cases(getitem_cases)


squeeze_cases = [
    (
        "squeeze",
        lambda: F.squeeze(vector_v),
    ),
    (
        "squeeze",
        lambda: F.squeeze(matrix_C, axes=(0,)),
    ),
]

render_cases(squeeze_cases)

unsqueeze_cases = [
    (
        "unsqueeze",
        lambda: F.unsqueeze(vector_v, axes=(0,)),
    ),
]

render_cases(unsqueeze_cases)

concatenate_cases = [
    (
        "concatenate",
        lambda: F.concatenate((tensor_T, tensor_T), axis=0),
    ),
]

render_cases(concatenate_cases)

hstack_cases = [
    (
        "hstack",
        lambda: F.hstack((tensor_T, tensor_T)),
    ),
]

render_cases(hstack_cases)

vstack_cases = [
    (
        "vstack",
        lambda: F.vstack((matrix_A, matrix_B)),
    ),
]

render_cases(vstack_cases)

vstack_cases2 = [
    (
        "vstack",
        lambda: F.vstack((matrix_D, matrix_B)),
    ),
]

render_cases(vstack_cases2)
# Out:
# $\displaystyle \text{getitem} = {T}_{:3:2,1:4:2,1}$
# $\displaystyle \text{squeeze} = \operatorname{squeeze}({v})$
# $\displaystyle \text{squeeze} = \operatorname{squeeze}(C;\, 0)$
# $\displaystyle \text{unsqueeze} = \operatorname{unsqueeze}(v;\, 0)$
# $\displaystyle \text{concatenate} = \operatorname{concat}((T,T);\, \mathrm{axis=0})$
# $\displaystyle \text{hstack} = [T\;T]$
# $\displaystyle \text{vstack} = \begin{bmatrix}A \\ B\end{bmatrix}$
# $\displaystyle \text{vstack} = \begin{bmatrix}\begin{bmatrix}1 & 2 & 3 \\ 4 & 5 & 6\end{bmatrix} \\ B\end{bmatrix}$

# %% [markdown]
# ## Comparison

# %%
comparison_cases = [
    ("eq", lambda: F.eq(scalar_a, scalar_b)),
    ("ne", lambda: F.ne(scalar_a, scalar_b)),
    ("lt", lambda: F.lt(scalar_a, scalar_b)),
    ("le", lambda: F.le(scalar_a, scalar_b)),
    ("gt", lambda: F.gt(scalar_a, scalar_b)),
    ("ge", lambda: F.ge(scalar_a, scalar_b)),
    ("not", lambda: F.logical_not(bool_vector_mask)),
    ("any", lambda: F.logical_any(bool_vector_mask)),
    ("all", lambda: F.logical_all(bool_matrix_flags)),
    ("and", lambda: F.logical_and(bool_vector_mask, bool_vector_mask_rhs)),
    ("or", lambda: F.logical_or(bool_vector_mask, bool_vector_mask_rhs)),
    ("xor", lambda: F.logical_xor(bool_matrix_flags, bool_matrix_flags_rhs)),
]

render_cases(comparison_cases)
# Out:
# $\displaystyle \text{eq} = a \equiv b$
# $\displaystyle \text{ne} = a \neq b$
# $\displaystyle \text{lt} = a < b$
# $\displaystyle \text{le} = a \le b$
# $\displaystyle \text{gt} = a > b$
# $\displaystyle \text{ge} = a \ge b$
# $\displaystyle \text{not} = \neg mask$
# $\displaystyle \text{any} = \operatorname{any}(\left(mask\right))$
# $\displaystyle \text{all} = \operatorname{all}(\left(flags\right))$
# $\displaystyle \text{and} = mask \land mask\_rhs$
# $\displaystyle \text{or} = mask \lor mask\_rhs$
# $\displaystyle \text{xor} = flags \oplus flags\_rhs$

# %%
with pm.new_context():
    pm.set_value(vector_u.name, [1.0, 2.0, 4.0])
    pm.set_value(vector_v.name, [1.0, 3.0, 9.0])
    print(F.eq(vector_u, vector_v).eval())
# end with
# Out:
# tensor([True, False, False], dtype=DType.BOOL, shape=(3,), mutable=True)

# %%
with pm.new_context():
    pm.set_value(bool_vector_mask.name, [True, False, True])
    pm.set_value(bool_vector_mask_rhs.name, [False, True, False])
    pm.set_value(bool_matrix_flags.name, [[True, False], [True, True]])
    pm.set_value(bool_matrix_flags_rhs.name, [[False, True], [True, False]])
    print("not(mask) ->", F.logical_not(bool_vector_mask).eval())
    print("and(mask, mask_rhs) ->", F.logical_and(bool_vector_mask, bool_vector_mask_rhs).eval())
    print("or(mask, mask_rhs) ->", F.logical_or(bool_vector_mask, bool_vector_mask_rhs).eval())
    print("xor(flags, flags_rhs) ->", F.logical_xor(bool_matrix_flags, bool_matrix_flags_rhs).eval())
    print("any(mask) ->", F.logical_any(bool_vector_mask).eval())
    print("all(flags) ->", F.logical_all(bool_matrix_flags).eval())
# end with
# Out:
# not(mask) -> tensor([False, True, False], dtype=DType.BOOL, shape=(3,), mutable=True)
# and(mask, mask_rhs) -> tensor([False, False, False], dtype=DType.BOOL, shape=(3,), mutable=True)
# or(mask, mask_rhs) -> tensor([True, True, True], dtype=DType.BOOL, shape=(3,), mutable=True)
# xor(flags, flags_rhs) -> tensor([[True, True], [False, True]], dtype=DType.BOOL, shape=(2, 2), mutable=True)
# any(mask) -> tensor(True, dtype=DType.BOOL, shape=(), mutable=True)
# all(flags) -> tensor(False, dtype=DType.BOOL, shape=(), mutable=True)
