# %%
import pixelprism.math as pm
import pixelprism.math.functional as F
from pixelprism.math.render import render_latex
# Out:
# /home/schaetti/Projets/CODING/PixelPrism/pixelprism/math/render/latex.py:1228: SyntaxWarning: invalid escape sequence '\i'
#   lower = "-\infty"
# /home/schaetti/Projets/CODING/PixelPrism/pixelprism/math/render/latex.py:1237: SyntaxWarning: invalid escape sequence '\i'
#   upper = "\infty"

# %%
x = pm.var("x", pm.DType.FLOAT32, pm.Shape.scalar())

# %%
dx_dx = x.diff(wrt=x)
dx_dx.eval()
# Out:
# tensor(1.0, dtype=DType.FLOAT32, shape=(), mutable=True)

# %%
c = pm.const("c", data=10, dtype=pm.DType.FLOAT32)
dc_dx = c.diff(wrt=x)
dc_dx.eval()
# Out:
# tensor(0.0, dtype=DType.FLOAT32, shape=(), mutable=True)

# %%
y = x + c
dy_dx = y.diff(wrt=x)
dy_dx
# Out:
# <MathNode #7 add float32 () c:2>

# %%
render_latex(y)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# pre-processing DVI file (format version 2)
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = x * x
dy_dx = y.diff(wrt=x)
dy_dx
# Out:
# <MathNode #13 add float32 () c:2>

# %%
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# pre-processing DVI file (format version 2)
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = x / x
dy_dx = y.diff(wrt=x)
dy_dx
# Out:
# <MathNode #21 div float32 () c:2>

# %%
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# pre-processing DVI file (format version 2)
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.pow(x, 3)
dy_dx = y.diff(wrt=x)
dy_dx
# Out:
# <MathNode #29 mul float32 () c:2>

# %%
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = (x + 1) ** 2
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# pre-processing DVI file (format version 2)
# processing page 1
#   computing extents based on data set by preview package (version 13.2)
#   width=84.645601pt, height=12.038913pt, depth=0pt
#   graphic size: 84.645601pt x 12.038913pt (84.329366bp x 11.993936bp)
#   output written to /tmp/tmpcnxvw2r0.svg
# 1 of 1 page converted in 0.0302401 seconds
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# ...

# %%
y = F.pow(x, -1)
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.pow(x, x)
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.exp(2 * x + 1)
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.exp2(2 * x + 1)
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.log(2 * x + 1)
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.sqrt(x)
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.square(x+1)
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...

# %%
y = F.cos(F.sin(x+1))
dy_dx = y.diff(wrt=x)
dy_dx
render_latex(dy_dx)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2025/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./tmp_latex/equation.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cls
# Document Class: standalone 2025/02/22 v1.5a Class to compile TeX sub-files stan
# dalone
# (/usr/share/texlive/texmf-dist/tex/latex/tools/shellesc.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifluatex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/keyval.tex))))
# (/usr/share/texlive/texmf-dist/tex/latex/standalone/standalone.cfg)
# ...
